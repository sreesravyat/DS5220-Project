# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.9.1-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jagad\conda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\jagad\conda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jagad\conda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jagad\conda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\jagad\conda3\lib\site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\jagad\conda3\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=8 in c:\users\jagad\conda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jagad\conda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jagad\conda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\jagad\conda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.9.1-cp311-cp311-win_amd64.whl (8.0 MB)
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.7/8.0 MB 13.9 MB/s eta 0:00:01
#    -------- ------------------------------- 1.7/8.0 MB 17.8 MB/s eta 0:00:01
#    -------------- ------------------------- 3.0/8.0 MB 21.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.5/8.0 MB 23.9 MB/s eta 0:00:01
#    ------------------------------- -------- 6.2/8.0 MB 26.4 MB/s eta 0:00:01
#    ---------------------------------------  8.0/8.0 MB 28.3 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 25.5 MB/s eta 0:00:00
# Installing collected packages: matplotlib
# Successfully installed matplotlib-3.9.1
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\jagad\conda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\jagad\conda3\Lib\site-packages)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

cardio_data = pd.read_csv("C:/Users/jagad/Downloads/archive (3)/cardio_train.csv")

features = ['age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo', 'cholesterol', 'gluc', 'smoke', 'alco', 'active']
target = 'cardio'

numeric_features = ['age', 'height', 'weight', 'ap_hi', 'ap_lo']
categorical_features = ['gender', 'cholesterol', 'gluc', 'smoke', 'alco', 'active']

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

X_train, X_test, y_train, y_test = train_test_split(cardio_data[features], cardio_data[target], test_size=0.2, random_state=42)

X_train = preprocessor.fit_transform(X_train)
X_test = preprocessor.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score

models = {
    'Logistic Regression': LogisticRegression(max_iter=1000),
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(),
    'SVM': SVC(probability=True)
}

for name, model in models.items():
    cv_scores = cross_val_score(model, X_train, y_train, cv=5, scoring='accuracy')
    print(f'{name} CV Accuracy: {cv_scores.mean()}')

best_model = RandomForestClassifier()
best_model.fit(X_train, y_train)
# Out:
# Logistic Regression CV Accuracy: 0.7194107142857143
# Decision Tree CV Accuracy: 0.6391428571428571
# Random Forest CV Accuracy: 0.7133571428571429
# SVM CV Accuracy: 0.7304285714285714
# RandomForestClassifier()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

y_pred = best_model.predict(X_test)
y_proba = best_model.predict_proba(X_test)[:, 1]

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_proba)

print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1-Score: {f1}')
print(f'ROC-AUC: {roc_auc}')
# Out:
# Accuracy: 0.7129285714285715
# Precision: 0.7181168925812563
# Recall: 0.7026525955504849
# F1-Score: 0.7103005838679448
# ROC-AUC: 0.7698365378869685

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, classification_report, roc_curve, auc
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

# Load dataset
cardio_data = pd.read_csv("C:/Users/jagad/Downloads/archive (3)/cardio_train.csv")

# Define features and target
features = ['age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo', 'cholesterol', 'gluc', 'smoke', 'alco', 'active']
target = 'cardio'

# %%
# Split data into numeric and categorical features
numeric_features = ['age', 'height', 'weight', 'ap_hi', 'ap_lo']
categorical_features = ['gender', 'cholesterol', 'gluc', 'smoke', 'alco', 'active']

# %%
# Preprocessing pipelines for numeric and categorical data
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

# %%
# Combine preprocessing steps
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

# %%
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(cardio_data[features], cardio_data[target], test_size=0.2, random_state=42)

# Apply preprocessing
X_train = preprocessor.fit_transform(X_train)
X_test = preprocessor.transform(X_test)

# %%
# Define models
models = {
    'Logistic Regression': LogisticRegression(max_iter=1000),
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(),
    'SVM': SVC(probability=True),
    'K-Nearest Neighbors': KNeighborsClassifier(),
    'Gradient Boosting': GradientBoostingClassifier()
}

# %%
# Hyperparameter tuning for Random Forest
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}
grid_search = GridSearchCV(RandomForestClassifier(), param_grid, cv=5, scoring='accuracy', n_jobs=-1)
grid_search.fit(X_train, y_train)
best_model = grid_search.best_estimator_

# %%
# Evaluate all models
results = {}
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    y_proba = model.predict_proba(X_test)[:, 1] if hasattr(model, "predict_proba") else None
    
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    roc_auc = roc_auc_score(y_test, y_proba) if y_proba is not None else None
    
    results[name] = {
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1': f1,
        'roc_auc': roc_auc
    }
    
    print(f'{name} Results:')
    print(f'Accuracy: {accuracy}')
    print(f'Precision: {precision}')
    print(f'Recall: {recall}')
    print(f'F1-Score: {f1}')
    if roc_auc is not None:
        print(f'ROC-AUC: {roc_auc}')
    print('\n')
    
    # Confusion matrix and classification report
    print('Confusion Matrix:')
    print(confusion_matrix(y_test, y_pred))
    print('Classification Report:')
    print(classification_report(y_test, y_pred))
    
    # ROC Curve
    if y_proba is not None:
        fpr, tpr, thresholds = roc_curve(y_test, y_proba)
        plt.figure()
        plt.plot(fpr, tpr, label=f'{name} (AUC = {roc_auc:.2f})')
        plt.plot([0, 1], [0, 1], 'k--')
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title(f'ROC Curve - {name}')
        plt.legend(loc='lower right')
        plt.show()

# Save the best model
joblib.dump(best_model, 'best_model.pkl')
# Out:
# Logistic Regression Results:
# Accuracy: 0.7221428571428572
# Precision: 0.7440587867417136
# Recall: 0.6786936679977182
# F1-Score: 0.7098747016706443
# ROC-AUC: 0.7866273423334142
#
#
# Confusion Matrix:
# [[5351 1637]
#  [2253 4759]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.70      0.77      0.73      6988
#            1       0.74      0.68      0.71      7012
#
#     accuracy                           0.72     14000
#    macro avg       0.72      0.72      0.72     14000
# weighted avg       0.72      0.72      0.72     14000
# Decision Tree Results:
# Accuracy: 0.6318571428571429
# Precision: 0.6304408873911822
# Recall: 0.6403308613804906
# F1-Score: 0.6353473892740908
# ROC-AUC: 0.6318800202188349
#
#
# Confusion Matrix:
# [[4356 2632]
#  [2522 4490]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.63      0.62      0.63      6988
#            1       0.63      0.64      0.64      7012
#
#     accuracy                           0.63     14000
#    macro avg       0.63      0.63      0.63     14000
# weighted avg       0.63      0.63      0.63     14000
# Random Forest Results:
# Accuracy: 0.7108571428571429
# Precision: 0.7155949956357288
# Recall: 0.7015116942384484
# F1-Score: 0.7084833645398242
# ROC-AUC: 0.7698045173847041
#
#
# Confusion Matrix:
# [[5033 1955]
#  [2093 4919]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.72      0.71      6988
#            1       0.72      0.70      0.71      7012
#
#     accuracy                           0.71     14000
#    macro avg       0.71      0.71      0.71     14000
# weighted avg       0.71      0.71      0.71     14000
# SVM Results:
# Accuracy: 0.7348571428571429
# Precision: 0.7503033980582524
# Recall: 0.7053622361665716
# F1-Score: 0.7271390767421347
# ROC-AUC: 0.7917170613725885
#
#
# Confusion Matrix:
# [[5342 1646]
#  [2066 4946]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.72      0.76      0.74      6988
#            1       0.75      0.71      0.73      7012
#
#     accuracy                           0.73     14000
#    macro avg       0.74      0.73      0.73     14000
# weighted avg       0.74      0.73      0.73     14000
# K-Nearest Neighbors Results:
# Accuracy: 0.6502857142857142
# Precision: 0.6554967666078777
# Recall: 0.6360524814603536
# F1-Score: 0.6456282570932252
# ROC-AUC: 0.6934924257736594
#
#
# Confusion Matrix:
# [[4644 2344]
#  [2552 4460]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.65      0.66      0.65      6988
#            1       0.66      0.64      0.65      7012
#
#     accuracy                           0.65     14000
#    macro avg       0.65      0.65      0.65     14000
# weighted avg       0.65      0.65      0.65     14000
# Gradient Boosting Results:
# Accuracy: 0.7375714285714285
# Precision: 0.752725620835857
# Recall: 0.7089275527666857
# F1-Score: 0.7301703877790835
# ROC-AUC: 0.8037594641094455
#
#
# Confusion Matrix:
# [[5355 1633]
#  [2041 4971]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.72      0.77      0.74      6988
#            1       0.75      0.71      0.73      7012
#
#     accuracy                           0.74     14000
#    macro avg       0.74      0.74      0.74     14000
# weighted avg       0.74      0.74      0.74     14000
# ['best_model.pkl']

# %%
# Feature importance for tree-based models
if hasattr(best_model, 'feature_importances_'):
    importances = best_model.feature_importances_
    feature_names = numeric_features + list(preprocessor.named_transformers_['cat']['onehot'].get_feature_names_out(categorical_features))
    feature_importance_df = pd.DataFrame({'feature': feature_names, 'importance': importances})
    feature_importance_df = feature_importance_df.sort_values(by='importance', ascending=False)
    
    plt.figure(figsize=(12, 6))
    sns.barplot(x='importance', y='feature', data=feature_importance_df)
    plt.title('Feature Importances')
    plt.show()
